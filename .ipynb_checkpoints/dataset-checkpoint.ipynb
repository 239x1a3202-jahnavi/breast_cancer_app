# %%
from sklearn.datasets import load_breast_cancer
import pandas as pd

# Load dataset
data = load_breast_cancer()

# Convert to DataFrame
X = pd.DataFrame(data.data, columns=data.feature_names)
y = pd.Series(data.target, name="Cancer")

print(X.head())
print(y.head())
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst radius  worst texture  worst perimeter  \
# 0                 0.07871  ...         25.38          17.33           184.60
# 1                 0.05667  ...         24.99          23.41           158.80
# 2                 0.05999  ...         23.57          25.53           152.50
# 3                 0.09744  ...         14.91          26.50            98.87
# 4                 0.05883  ...         22.54          16.67           152.20
#
#    worst area  worst smoothness  worst compactness  worst concavity  \
# 0      2019.0            0.1622             0.6656           0.7119
# 1      1956.0            0.1238             0.1866           0.2416
# 2      1709.0            0.1444             0.4245           0.4504
# 3       567.7            0.2098             0.8663           0.6869
# 4      1575.0            0.1374             0.2050           0.4000
#
#    worst concave points  worst symmetry  worst fractal dimension
# 0                0.2654          0.4601                  0.11890
# 1                0.1860          0.2750                  0.08902
# 2                0.2430          0.3613                  0.08758
# 3                0.2575          0.6638                  0.17300
# 4                0.1625          0.2364                  0.07678
#
# [5 rows x 30 columns]
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: Cancer, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

X_scaled = scaler.fit_transform(X)

# %%
import numpy as np

print(np.mean(X_scaled))   # should be close to 0
print(np.std(X_scaled))    # should be close to 1
# Out:
# -6.393635864836051e-16
# 1.0

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y,
    test_size=0.2,
    random_state=42
)

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (455, 30)
# (114, 30)

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression(max_iter=1000)

model.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.9736842105263158

# %%
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[41  2]
#  [ 1 70]]

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.95      0.96        43
#            1       0.97      0.99      0.98        71
#
#     accuracy                           0.97       114
#    macro avg       0.97      0.97      0.97       114
# weighted avg       0.97      0.97      0.97       114

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf_model = RandomForestClassifier(
    n_estimators=100,
    random_state=42
)

rf_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_pred_rf = rf_model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

print("Random Forest Accuracy:", accuracy_score(y_test, y_pred_rf))
# Out:
# Random Forest Accuracy: 0.9649122807017544

# %%
pip install streamlit
# Out:
# Requirement already satisfied: streamlit in c:\users\jahna\appdata\roaming\python\python312\site-packages (1.52.2)
# Requirement already satisfied: altair!=5.4.0,!=5.4.1,<7,>=4.0 in c:\users\jahna\appdata\roaming\python\python312\site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in c:\users\jahna\appdata\roaming\python\python312\site-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<7,>=4.0 in c:\users\jahna\appdata\roaming\python\python312\site-packages (from streamlit) (6.2.4)
# Requirement already satisfied: click<9,>=7.0 in c:\users\jahna\appdata\roaming\python\python312\site-packages (from streamlit) (8.3.1)
# Requirement already satisfied: numpy<3,>=1.23 in c:\users\jahna\appdata\roaming\python\python312\site-packages (from streamlit) (1.26.4)
# Requirement already satisfied: packaging>=20 in c:\users\jahna\appdata\roaming\python\python312\site-packages (from streamlit) (25.0)
# Requirement already satisfied: pandas<3,>=1.4.0 in c:\users\jahna\appdata\roaming\python\python312\site-packages (from streamlit) (2.3.3)
# Requirement already satisfied: pillow<13,>=7.1.0 in c:\users\jahna\appdata\roaming\python\python312\site-packages (from streamlit) (12.0.0)
# Requirement already satisfied: protobuf<7,>=3.20 in c:\users\jahna\appdata\roaming\python\python312\site-packages (from streamlit) (6.33.2)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\jahna\appdata\roaming\python\python312\site-packages (from streamlit) (22.0.0)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\jahna\appdata\roaming\python\python312\site-packages (from streamlit) (2.32.5)
# Requirement already satisfied: tenacity<10,>=8.1.0 in c:\users\jahna\appdata\roaming\python\python312\site-packages (from streamlit) (9.1.2)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\jahna\appdata\roaming\python\python312\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in c:\users\jahna\appdata\roaming\python\python312\site-packages (from streamlit) (4.15.0)
# Requirement already satisfied: watchdog<7,>=2.1.5 in c:\users\jahna\appdata\roaming\python\python312\site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\jahna\appdata\roaming\python\python312\site-packages (from streamlit) (3.1.45)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\users\jahna\appdata\roaming\python\python312\site-packages (from streamlit) (0.9.1)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in c:\users\jahna\appdata\roaming\python\python312\site-packages (from streamlit) (6.5.4)
# Requirement already satisfied: jinja2 in c:\users\jahna\appdata\roaming\python\python312\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\jahna\appdata\roaming\python\python312\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (4.25.1)
# Requirement already satisfied: narwhals>=1.27.1 in c:\users\jahna\appdata\roaming\python\python312\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2.14.0)
# Requirement already satisfied: colorama in c:\users\jahna\appdata\roaming\python\python312\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\jahna\appdata\roaming\python\python312\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\jahna\appdata\roaming\python\python312\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\jahna\appdata\roaming\python\python312\site-packages (from pandas<3,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jahna\appdata\roaming\python\python312\site-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\jahna\appdata\roaming\python\python312\site-packages (from pandas<3,>=1.4.0->streamlit) (2025.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\jahna\appdata\roaming\python\python312\site-packages (from requests<3,>=2.27->streamlit) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jahna\appdata\roaming\python\python312\site-packages (from requests<3,>=2.27->streamlit) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\jahna\appdata\roaming\python\python312\site-packages (from requests<3,>=2.27->streamlit) (2.6.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jahna\appdata\roaming\python\python312\site-packages (from requests<3,>=2.27->streamlit) (2025.11.12)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\jahna\appdata\roaming\python\python312\site-packages (from jinja2->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\jahna\appdata\roaming\python\python312\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\jahna\appdata\roaming\python\python312\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\jahna\appdata\roaming\python\python312\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\jahna\appdata\roaming\python\python312\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (0.30.0)
# Requirement already satisfied: six>=1.5 in c:\users\jahna\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
